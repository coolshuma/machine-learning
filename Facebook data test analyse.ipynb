# %% [markdown]
# # Анализ массива данных

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Загрузим данные

# %%
data = pd.read_csv('dataset_Facebook.csv', sep=';')

# %%
data.shape
# Out:
# (500, 19)

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ## Числовое представление данных

# %% [markdown]
# ### Для всех данных

# %% [markdown]
# Вычисление среднего, максимального/минимального значений, медианы, моды числовых значений как для всего массива в целом, так и для каждого типа контента (столбец Type) в отдельности. Найти самый популярный объект в выборке, объяснить почему

# %% [markdown]
# Общее описание. Вычисление среднего, максимального/минимального значений:

# %%
data.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %% [markdown]
# Медиана:

# %%
data.median()
# Out:
# Page total likes                                                       129600.0
# Category                                                                    2.0
# Post Month                                                                  7.0
# Post Weekday                                                                4.0
# Post Hour                                                                   9.0
# Paid                                                                        0.0
# Lifetime Post Total Reach                                                5281.0
# Lifetime Post Total Impressions                                          9051.0
# Lifetime Engaged Users                                                    625.5
# Lifetime Post Consumers                                                   551.5
# Lifetime Post Consumptions                                                851.0
# Lifetime Post Impressions by people who have liked your Page             6255.5
# ...

# %% [markdown]
# Мода

# %%
data[data['Page total likes'] == 136393.0]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 119            136393   Photo         1          10             7         10
# 120            136393   Photo         1          10             7          9
# 121            136393  Status         2          10             7          9
# 122            136393   Photo         1          10             7          8
# 123            136393   Photo         1          10             7          7
# 124            136393   Photo         1          10             7          6
# 125            136393   Photo         1          10             7          5
# 126            136393   Photo         3          10             7          3
# 127            136393   Photo         1          10             6         13
# 128            136393   Photo         1          10             6         13
# 129            136393   Photo         1          10             6         12
# ...

# %%
data.mode().loc[0]
# Out:
# Page total likes                                                       136393
# Type                                                                    Photo
# Category                                                                    1
# Post Month                                                                 10
# Post Weekday                                                                7
# Post Hour                                                                   3
# Paid                                                                        0
# Lifetime Post Total Reach                                                 677
# Lifetime Post Total Impressions                                          4372
# Lifetime Engaged Users                                                    537
# Lifetime Post Consumers                                                   182
# Lifetime Post Consumptions                                                431
# ...

# %% [markdown]
# ### Для каждого типа контента

# %% [markdown]
# Посмотрим какие типы контента вообще существуют

# %%
types = data.Type.value_counts()
types
# Out:
# Photo     426
# Status     45
# Link       22
# Video       7
# Name: Type, dtype: int64

# %% [markdown]
# Посчитаем те же самые значения для каждого типа:

# %%
for cur_type in types.index:
    print "Для типа", cur_type
    print "Общее описание:"
    display(data[data.Type == cur_type].describe())
    print "Медиана:"
    print data.median()
    print 
    print "Мода:"
    print data.mode().loc[0]
    print
# Out:
# Для типа Photo
# Общее описание:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        426.000000  426.000000  426.000000    426.000000  426.000000
# mean      122354.171362    1.917840    6.805164      4.107981    7.997653
# std        16324.528694    0.884007    3.234676      2.056286    4.413082
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       109670.000000    1.000000    4.000000      2.000000    3.000000
# 50%       128032.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136013.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  425.000000                 426.000000                     4.260000e+02
# mean     0.280000               13137.814554                     2.899450e+04
# ...

# %% [markdown]
# Самый популярный объект в выборке

# %%
data[data.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Page total likes, Type, Category, Post Month, Post Weekday, Post Hour, Paid, Lifetime Post Total Reach, Lifetime Post Total Impressions, Lifetime Engaged Users, Lifetime Post Consumers, Lifetime Post Consumptions, Lifetime Post Impressions by people who have liked your Page, Lifetime Post reach by people who like your Page, Lifetime People who have liked your Page and engaged with your post, comment, like, share, Total Interactions]
# Index: []

# %% [markdown]
# Судя по всему в данных нет повторяющихся колнок, а значит нет и самого популярного элемента -- все элементы встречаются по одному разу
